# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Data

# %%
derm_all = np.array([(1, 79.43),(2, 85.19),(3, 79.32),(4, 84.81), (5, 73.96), (6, 83.85), (7, 69.57),
                    (8, 83.07), (9, 67.64), (10, 82.77)])
derm_ense = np.array([(0.8, 79.8), (10.2, 79.8)])

clin_all = np.array([(1, 81.42), (2, 84.99), (3, 80.67), (4, 83.15), (5, 75.64), (6, 82.46), (7, 68.42), 
                     (8, 82.01), (9, 66.68), (10, 82.03)])
clin_ense = np.array([(0.8, 80.7), (10, 80.7)])

# %% [markdown]
# ## Plot

# %%
plt.subplot(221)
plt.plot(derm_ense[:,0], derm_ense[:,1], color='r', linestyle='dashed')
plt.plot(derm_all[:,0], derm_all[:,1], color='b', marker='s', markersize=3.5, linestyle='dashed')
plt.grid(color='black', linestyle='dotted', linewidth=0.7)
plt.axis((0.9,10.1,60,90))
plt.legend(['Ensemble','Higher orders'], loc='lower left')
plt.xlabel("Order of Gram Matrix")
plt.ylabel("TNR @ TPR95") 
plt.title("ISIC-2019 vs Derm-Skin")


plt.subplot(222)
plt.plot(clin_ense[:,0], clin_ense[:,1], color='r', linestyle='dashed')
plt.plot(clin_all[:,0], clin_all[:,1], color='b', marker='s', markersize=3.5, linestyle='dashed')
plt.grid(color='black', linestyle='dotted', linewidth=0.7)
plt.axis((0.9,10.1,60,90))
plt.legend(['Ensemble','Higher orders'], loc='lower left')
plt.xlabel("Order of Gram Matrix")

plt.title("ISIC-2019 vs Clin-Skin")

plt.tight_layout()
plt.savefig("ensemble_effect", dpi = 300)
